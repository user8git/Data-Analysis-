# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv ('D:/Padmaja/Unified Mentor/Projects/google_cleaned (2).csv')

# %%
df.head()
df.notna().sum()
# Out:
# Unnamed: 0        10840
# App               10840
# Category          10840
# Rating            10840
# Reviews           10840
# Size              10840
# Installs          10840
# Type              10840
# Price             10840
# Content Rating    10840
# Genres            10840
# Current Ver       10840
# Android Ver       10840
# Day               10840
# month             10840
# year              10840
# dtype: int64

# %%
df.notna().sum()
# Out:
# Unnamed: 0        10840
# App               10840
# Category          10840
# Rating            10840
# Reviews           10840
# Size              10840
# Installs          10840
# Type              10840
# Price             10840
# Content Rating    10840
# Genres            10840
# Current Ver       10840
# Android Ver       10840
# Day               10840
# month             10840
# year              10840
# dtype: int64

# %%
df.shape
# Out:
# (10840, 16)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        Unnamed: 0                                                App  \
# 0               0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1               1                                Coloring book moana
# 2               2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3               3                              Sketch - Draw & Paint
# 4               4              Pixel Draw - Number Art Coloring Book
# ...           ...                                                ...
# 10835       10836                                   Sya9a Maroc - FR
# 10836       10837                   Fr. Mike Schmitz Audio Teachings
# 10837       10838                             Parkinson Exercices FR
# 10838       10839                      The SCP Foundation DB fr nn5n
# 10839       10840      iHoroscope - 2018 Daily Horoscope & Astrology
#
#                   Category    Rating  Reviews          Size  Installs  Type  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10840 entries, 0 to 10839
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      10840 non-null  int64
#  1   App             10840 non-null  object
#  2   Category        10840 non-null  object
#  3   Rating          10840 non-null  float64
#  4   Reviews         10840 non-null  int64
#  5   Size            10840 non-null  float64
#  6   Installs        10840 non-null  int64
#  7   Type            10840 non-null  object
#  8   Price           10840 non-null  float64
#  9   Content Rating  10840 non-null  object
#  10  Genres          10840 non-null  object
#  11  Current Ver     10840 non-null  object
#  12  Android Ver     10840 non-null  object
#  13  Day             10840 non-null  int64
#  14  month           10840 non-null  int64
#  15  year            10840 non-null  int64
# dtypes: float64(3), int64(6), object(7)
# ...

# %%
print("Columns:", df.columns.tolist())
# Out:
# Columns: ['Unnamed: 0', 'App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Current Ver', 'Android Ver', 'Day', 'month', 'year']

# %%
print("\nMissing values:\n", df.isnull().sum())
# Out:
# Missing values:
#  Unnamed: 0        0
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Current Ver       0
# Android Ver       0
# Day               0
# month             0
# year              0
# dtype: int64

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        Unnamed: 0                                                App  \
# 0               0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1               1                                Coloring book moana
# 2               2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3               3                              Sketch - Draw & Paint
# 4               4              Pixel Draw - Number Art Coloring Book
# ...           ...                                                ...
# 10835       10836                                   Sya9a Maroc - FR
# 10836       10837                   Fr. Mike Schmitz Audio Teachings
# 10837       10838                             Parkinson Exercices FR
# 10838       10839                      The SCP Foundation DB fr nn5n
# 10839       10840      iHoroscope - 2018 Daily Horoscope & Astrology
#
#                   Category    Rating  Reviews          Size  Installs  Type  \
# ...

# %%
print("Duplicates:", df.duplicated(subset=['App']).sum())
# Out:
# Duplicates: 1181

# %%
# Convert Reviews → numeric
df['Reviews'] = pd.to_numeric(df['Reviews'], errors='coerce')

# %%
df['Price'] = pd.to_numeric(df['Price'], errors='coerce')

# %%
print(df)
# Out:
#        Unnamed: 0                                                App  \
# 0               0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1               1                                Coloring book moana
# 2               2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3               3                              Sketch - Draw & Paint
# 4               4              Pixel Draw - Number Art Coloring Book
# ...           ...                                                ...
# 10835       10836                                   Sya9a Maroc - FR
# 10836       10837                   Fr. Mike Schmitz Audio Teachings
# 10837       10838                             Parkinson Exercices FR
# 10838       10839                      The SCP Foundation DB fr nn5n
# 10839       10840      iHoroscope - 2018 Daily Horoscope & Astrology
#
#                   Category    Rating  Reviews          Size  Installs  Type  \
# ...

# %%
# Fill Rating with median
df['Rating'].fillna(df['Rating'].median(), inplace=True)
# Out:
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_28176\4091223944.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Rating'].fillna(df['Rating'].median(), inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.drop_duplicates(inplace=True)

# %%
print("\nShape After Cleaning:", df.shape)
print("\nMissing Values After Cleaning:\n", df.isnull().sum())
print("\nPreview of Cleaned Data:\n", df.head())
# Out:
# Shape After Cleaning: (10840, 16)
#
# Missing Values After Cleaning:
#  Unnamed: 0        0
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Current Ver       0
# Android Ver       0
# Day               0
# month             0
# year              0
# dtype: int64
#
# Preview of Cleaned Data:
#     Unnamed: 0                                                App  \
# 0           0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1           1                                Coloring book moana
# 2           2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3           3                              Sketch - Draw & Paint
# 4           4              Pixel Draw - Number Art Coloring Book
#
#          Category  Rating  Reviews     Size  Installs  Type  Price  \
# ...

# %%
# Rating Graph
plt.figure(figsize=(8,6))
sns.histplot(df['Rating'], bins=25, kde=True)
plt.title("Distribution of App Ratings")
plt.show()

# %%
plt.figure(figsize=(12,6))
top_categories = df['Category'].value_counts().head(10)
sns.barplot(x=top_categories.index, y=top_categories.values, palette="coolwarm")
plt.title("Top 10 Categories by Number of Apps")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_28176\3119366119.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_categories.index, y=top_categories.values, palette="coolwarm")

# %%
filtered_df = df[df['Type'] == 'Paid']
print (filtered_df)
# count = filtered_df.shape[0]
# print(count)
# Out:
#        Unnamed: 0                                            App  \
# 234           234  TurboScan: scan documents and receipts in PDF
# 235           235                 Tiny Scanner Pro: PDF Doc Scan
# 290           290  TurboScan: scan documents and receipts in PDF
# 291           291                 Tiny Scanner Pro: PDF Doc Scan
# 427           427                             Puffin Browser Pro
# ...           ...                                            ...
# 10734       10735                                    FP VoiceBot
# 10759       10760                                Fast Tract Diet
# 10781       10782                        Trine 2: Complete Story
# 10784       10785                                   sugar, sugar
# 10797       10798                           Word Search Tab 1 FR
#
#                  Category    Rating  Reviews          Size  Installs  Type  \
# 234              BUSINESS  4.700000    11442   6800.000000    100000  Paid
# ...

# %%
df.columns = df.columns.str.strip()

# %%
count = filtered_df.shape[0]
print(count)
# Out:
# 800

# %%
filtered_df = df[df['Type'] == 'Paid']
print (filtered_df)
# Out:
#        Unnamed: 0                                            App  \
# 234           234  TurboScan: scan documents and receipts in PDF
# 235           235                 Tiny Scanner Pro: PDF Doc Scan
# 290           290  TurboScan: scan documents and receipts in PDF
# 291           291                 Tiny Scanner Pro: PDF Doc Scan
# 427           427                             Puffin Browser Pro
# ...           ...                                            ...
# 10734       10735                                    FP VoiceBot
# 10759       10760                                Fast Tract Diet
# 10781       10782                        Trine 2: Complete Story
# 10784       10785                                   sugar, sugar
# 10797       10798                           Word Search Tab 1 FR
#
#                  Category    Rating  Reviews          Size  Installs  Type  \
# 234              BUSINESS  4.700000    11442   6800.000000    100000  Paid
# ...

# %%
count = filtered_df.shape[0]
print(count)
# Out:
# 800

# %%
df['Type'] = df['Type'].astype(str).str.strip()
df[df['Type'].str.contains('Paid', case=False, na=False)]
# Out:
#        Unnamed: 0                                            App  \
# 234           234  TurboScan: scan documents and receipts in PDF
# 235           235                 Tiny Scanner Pro: PDF Doc Scan
# 290           290  TurboScan: scan documents and receipts in PDF
# 291           291                 Tiny Scanner Pro: PDF Doc Scan
# 427           427                             Puffin Browser Pro
# ...           ...                                            ...
# 10734       10735                                    FP VoiceBot
# 10759       10760                                Fast Tract Diet
# 10781       10782                        Trine 2: Complete Story
# 10784       10785                                   sugar, sugar
# 10797       10798                           Word Search Tab 1 FR
#
#                  Category    Rating  Reviews          Size  Installs  Type  \
# 234              BUSINESS  4.700000    11442   6800.000000    100000  Paid
# ...

# %%
filtered_df = df[df['Type'] == 'Paid']
print (filtered_df)
# Out:
#        Unnamed: 0                                            App  \
# 234           234  TurboScan: scan documents and receipts in PDF
# 235           235                 Tiny Scanner Pro: PDF Doc Scan
# 290           290  TurboScan: scan documents and receipts in PDF
# 291           291                 Tiny Scanner Pro: PDF Doc Scan
# 427           427                             Puffin Browser Pro
# ...           ...                                            ...
# 10734       10735                                    FP VoiceBot
# 10759       10760                                Fast Tract Diet
# 10781       10782                        Trine 2: Complete Story
# 10784       10785                                   sugar, sugar
# 10797       10798                           Word Search Tab 1 FR
#
#                  Category    Rating  Reviews          Size  Installs  Type  \
# 234              BUSINESS  4.700000    11442   6800.000000    100000  Paid
# ...

# %%
df['Type'].unique()
# Out:
# array(['Free', 'Paid'], dtype=object)

# %%
print(df[['App', 'Type', 'Price']].head(20))
# Out:
#                                                   App  Type  Price
# 0      Photo Editor & Candy Camera & Grid & ScrapBook  Free    0.0
# 1                                 Coloring book moana  Free    0.0
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...  Free    0.0
# 3                               Sketch - Draw & Paint  Free    0.0
# 4               Pixel Draw - Number Art Coloring Book  Free    0.0
# 5                          Paper flowers instructions  Free    0.0
# 6             Smoke Effect Photo Maker - Smoke Editor  Free    0.0
# 7                                    Infinite Painter  Free    0.0
# 8                                Garden Coloring Book  Free    0.0
# 9                       Kids Paint Free - Drawing Fun  Free    0.0
# 10                            Text on Photo - Fonteee  Free    0.0
# 11            Name Art Photo Editor - Focus n Filters  Free    0.0
# 12                     Tattoo Name On My Photo Editor  Free    0.0
# ...

# %%
df.head(10)
# Out:
#    Unnamed: 0                                                App  \
# 0           0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1           1                                Coloring book moana
# 2           2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3           3                              Sketch - Draw & Paint
# 4           4              Pixel Draw - Number Art Coloring Book
# 5           5                         Paper flowers instructions
# 6           6            Smoke Effect Photo Maker - Smoke Editor
# 7           7                                   Infinite Painter
# 8           8                               Garden Coloring Book
# 9           9                      Kids Paint Free - Drawing Fun
#
#          Category  Rating  Reviews     Size  Installs  Type  Price  \
# 0  ART_AND_DESIGN     4.1      159  19000.0     10000  Free    0.0
# 1  ART_AND_DESIGN     3.9      967  14000.0    500000  Free    0.0
# ...

# %%
df['Type'].value_counts()
# Out:
# Type
# Free    10040
# Paid      800
# Name: count, dtype: int64

# %%
df['Type'].unique()
# Out:
# array(['Free', 'Paid'], dtype=object)

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="Type", data=df, palette="Set2")
plt.title("Free vs Paid Apps")
plt.show()
# Out:
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_28176\2689774684.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Type", data=df, palette="Set2")

# %%
# Price distribution (Paid apps only)
plt.figure(figsize=(8,5))
sns.histplot(df[df['Type']=="Paid"]['Price'], bins=30, color="orange")
plt.title("Price Distribution of Paid Apps")
plt.show()

# %%
# Content Rating distribution
plt.figure(figsize=(8,5))
sns.countplot(x="Content Rating", data=df, palette="muted")
plt.title("Distribution of Content Rating")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Padmaja\AppData\Local\Temp\ipykernel_28176\2971969194.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Content Rating", data=df, palette="muted")

# %%
# Correlation heatmap
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()
